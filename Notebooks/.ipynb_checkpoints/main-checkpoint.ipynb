# %%
from src.preprocessing import dynamic_preprocessor
from src.model import train_model
from src.utils import save_baseline_stats

def main():
    x_old,y_old=dynamic_preprocessor("data/adult_income.csv","income")
    x_new,y_new=dynamic_preprocessor("data/adult_income.csv","income")
    model, train_inputs, acc=train_model(x_old,y_old)
    save_baseline_stats(train_inputs)


if __name__=="__main__":
    main()
# Out:
# Preprocesing is done!
# Model trained
# Baseline Accuracy: 0.8506064793489944
